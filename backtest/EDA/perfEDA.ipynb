# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def perf(path,name):
    df = pd.read_csv(f'{path}{name}.csv',index_col=0)
    df.columns =  ['tp'+str(col) for col in df.columns.tolist()]
    df.index = ['er'+str(ind) for ind in df.index.tolist()]
    df
    print(f'【{name}】')
    plt.figure(figsize=(10,6))
    sns.heatmap(df,annot=True ,linewidths=0.5,cmap="YlGnBu")
    plt.show()

# %% [markdown]
# # V3版本，10个小币种，每次选er最大1个币

# %%
path = '../testSFUDFXSAMD/perf/perf_v3/'
# perf(path,'annualizedReturn')
perf(path,'sharpeRatio')
# perf(path,'maxDrawdown')
# Out:
# 【sharpeRatio】

# %% [markdown]
# # V4版本，10个小币种，每次选er最大2个币

# %%
path = '../testSFUDFXSAMD/perf/perf_v4/'
# perf(path,'annualizedReturn')
perf(path,'sharpeRatio')
# perf(path,'maxDrawdown')
# Out:
# 【sharpeRatio】

# %% [markdown]
# # V5版本，10个小币种，每次选er最大1个币，新增出场条件

# %%
path = '../testSFUDFXSAMD/perf/perf_v5/'
# perf(path,'annualizedReturn')
perf(path,'sharpeRatio')
# perf(path,'maxDrawdown')
# Out:
# 【sharpeRatio】

# %% [markdown]
# # V3版本，5个长历史币种，每次选er最大1个币

# %%
path = '../testBBELB/perf/perf_v3/'
# perf(path,'annualizedReturn')
perf(path,'sharpeRatio')
# perf(path,'maxDrawdown')
# Out:
# 【sharpeRatio】

# %% [markdown]
# # V4版本，5个长历史币种，每次选er最大2个币

# %%
path = '../testBBELB/perf/perf_v4/'
# perf(path,'annualizedReturn')
perf(path,'sharpeRatio')
# perf(path,'maxDrawdown')
# Out:
# 【sharpeRatio】

# %% [markdown]
# # V5版本，5个长历史币种，每次选er最大1个币，XIN
